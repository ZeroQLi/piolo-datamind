# %%
import pandas as pd
from fastai.vision.all import *
from fastai.torch_basics import *
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ## Paths may have to be adjusted for in the below cell

# %%
data_path = './dataset/train/'
images_path= data_path + 'images/'
test_path = './dataset/test/images/'
csv_path = data_path + 'labels.csv'
submission_file = 'submission.csv'

# %%
files = get_image_files(images_path)
df = pd.read_csv(csv_path)

# %%
from matplotlib.pyplot import savefig


df['emp_id'].value_counts().plot(kind='bar', figsize=(12, 6), )
plt.title('Number of images per employee')
plt.xlabel('Employee ID')
plt.ylabel('Number of images')

savefig('demo.png', transparent=True)

# %%
# Create ImageDataLoaders from CSV
dls = ImageDataLoaders.from_csv(
    path=data_path,
    csv_fname='labels.csv',
    folder='images',
    fn_col='filename',
    label_col='emp_id',
    valid_pct=0.2,
    item_tfms=Resize(224),
    batch_tfms=aug_transforms(size=224)
)
# Show batch to verify the data loading
dls.show_batch()

# %%
learn = vision_learner(dls, resnet152, metrics=accuracy)
learn.fine_tune(1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
# ...

# %%
def predict_image(image):
	return learn.predict(test_path+image)[0]
#test_path
results = []

# %%
for image in os.listdir(test_path):
	prediction = dict(filename=image, emp_id=predict_image(image))
	results.append(prediction)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 2
#       1 for image in os.listdir(test_path):
# ----> 2 	prediction = dict(filename=image, emp_id=predict_image(image))
#       3 	results.append(prediction)
#
# Cell In[7], line 2, in predict_image(image)
#       1 def predict_image(image):
# ----> 2 	return learn.predict(test_path+image)[0]
#
# File ~/webdev/aura-datamind/.venv/lib/python3.11/site-packages/fastai/learner.py:329, in Learner.predict(self, item, rm_type_tfms, with_input)
#     327 def predict(self, item, rm_type_tfms=None, with_input=False):
#     328     dl = self.dls.test_dl([item], rm_type_tfms=rm_type_tfms, num_workers=0)
# --> 329     inp,preds,_,dec_preds = self.get_preds(dl=dl, with_input=True, with_decoded=True)
#     330     i = getattr(self.dls, 'n_inp', -1)
#     331     inp = (inp,) if i==1 else tuplify(inp)
#
# ...

# %%
results_df = pd.DataFrame.from_dict(results)
hi = results_df.drop_duplicates()
hi

# %%
hi.to_csv(submission_file, index=False)
